# %%
data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": [0.973, 0.985, 0.953, 0.991],
    "mp log_kvrh": [0.1707, 0.169, 0.168, 0.1652],
    "mp log_gvrh": [0.172, 0.169, 0.167, 0.164],
    "mp dielectric": [2.029, 2.0294, 2.207, 2.275]
}

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": [0.973, 0.985, 0.953, 0.991],
    "mp log_kvrh": [0.1707, 0.169, 0.168, 0.1652],
    "mp log_gvrh": [0.172, 0.169, 0.167, 0.164],
    "mp dielectric": [2.029, 2.0294, 2.207, 2.275]
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Plotting bar charts
width = 0.2  # Width of each bar
fig, ax = plt.subplots(figsize=(10, 6))

for i, prop in enumerate(properties):
    x_positions = np.arange(len(datasets)) + i * width
    ax.bar(x_positions, data[prop], width, label=prop)

ax.set_xticks(np.arange(len(datasets)) + (len(properties) - 1) * width / 2)
ax.set_xticklabels(datasets)
ax.set_xlabel('Dataset')
ax.set_ylabel('Property Values')
ax.legend()

plt.title('Bar Plot for Different Properties')
plt.show()

# %%
import matplotlib.pyplot as plt

data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": [0.973, 0.985, 0.953, 0.991],
    "mp log_kvrh": [0.1707, 0.169, 0.168, 0.1652],
    "mp log_gvrh": [0.172, 0.169, 0.167, 0.164],
    "mp dielectric": [2.029, 2.0294, 2.207, 2.275]
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

for prop in properties:
    ax.plot(datasets, data[prop], label=prop, marker='o')

ax.set_xlabel('Dataset size (in thousands)')
ax.set_ylabel('RMSError')
ax.legend()

plt.title('Composition')

# Save the plot in good quality as a PNG file
plt.savefig('composition_line_properties.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": [0.973, 0.985, 0.953, 0.991],
    "mp log_kvrh": [0.1707, 0.169, 0.168, 0.1652],
    "mp log_gvrh": [0.172, 0.169, 0.167, 0.164],
    "mp dielectric": [2.029, 2.0294, 2.207, 2.275]
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Transforming data to logarithmic scale
log_datasets = np.log10(datasets)
log_data = {prop: np.log10(values) for prop, values in data.items() if prop != "Dataset"}

# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

for prop in properties:
    ax.plot(log_datasets, log_data[prop], label=prop, marker='o')


ax.set_ylim(-1.2,0.4)

# Set font size
fontsize = 24

ax.set_xlabel('Dataset size (in thousands)')
ax.set_ylabel('RMSError')
ax.legend()

plt.title('Composition Learning(log scale)')

# Save the plot in good quality as a PNG file
plt.savefig('composition_log_line_plot_properties.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": [0.614, 0.1016, 0.095, np.nan],
    "mp log_kvrh": [0.296, 0.15726, 0.1453, 0.144],
    "mp log_gvrh": [0.298, 0.165, 0.153, 0.149],
    "mp dielectric": [1.902, 1.81, 1.766, 1.776]
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Handling the missing value in the provided data
data["mp perovskite form E"][-1] = np.nan

# Transforming data to logarithmic scale
log_datasets = np.log10(datasets)
log_data = {prop: np.log10(values) if prop != "Dataset" else values for prop, values in data.items()}

# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

for prop in properties:
    ax.plot(log_datasets, log_data[prop], label=prop, marker='o')


ax.set_ylim(-1.2,0.4)

# Set font size
fontsize = 24

ax.set_xlabel('Dataset size (in thousands)')
ax.set_ylabel('RMSError')
ax.legend()

plt.title('SLICES Learning (log scale)')

# Save the plot in good quality as a PNG file
plt.savefig('slice_log_line_plot_properties.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
data = {
    "Composition": [0.953, 0.168, 0.167, 2.207],
    "CrabNet": [0.5412, 0.1471, 0.1604, 1.7288],
    "CGCNN": [0.0722, 0.1301, 0.1337, 1.8976],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
    "SOTA": [0.0554, 0.1037, 0.1078, 1.6832]
}

# %%
def set_custom_style():
    plt.rcParams['figure.figsize'] = [3.3, 2.5]
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.major.width'] = 0.5
    plt.rcParams['xtick.minor.size'] = 1.5
    plt.rcParams['xtick.minor.width'] = 0.5
    plt.rcParams['xtick.minor.visible'] = True
    plt.rcParams['xtick.top'] = False
    plt.rcParams['xtick.minor.top'] = False
    plt.rcParams['xtick.minor.bottom'] = False
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.major.width'] = 0.5
    plt.rcParams['ytick.minor.size'] = 1.5
    plt.rcParams['ytick.minor.width'] = 0.5
    plt.rcParams['ytick.minor.visible'] = True
    plt.rcParams['ytick.minor.left'] = False
    plt.rcParams['ytick.right'] = False
    plt.rcParams['axes.linewidth'] = 0.5
    plt.rcParams['grid.linewidth'] = 0.5
    plt.rcParams['lines.linewidth'] = 1.
    plt.rcParams['lines.markersize'] = 3
    plt.rcParams['axes.xmargin'] = 0
    plt.rcParams['axes.ymargin'] = 0
    plt.rcParams['legend.frameon'] = False
    plt.rcParams['axes.labelsize'] = 20
    plt.rcParams['xtick.labelsize'] = 20
    plt.rcParams['ytick.labelsize'] = 20
    plt.rcParams['legend.fontsize'] = 20
    plt.rcParams['font.size'] = 15
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['CMU Sans Serif', 'IBM Plex Sans', 'Roboto', 'Helvetica']
    plt.rcParams['mathtext.fontset'] = 'dejavusans'
    plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{amssymb} \usepackage{sfmath}'
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.axisbelow'] = True
    plt.rcParams['text.color'] = '#758D99'
    plt.rcParams['axes.labelcolor'] = '#758D99'
    plt.rcParams['axes.edgecolor'] = '#758D99'
    plt.rcParams['xtick.color'] = '#758D99'
    plt.rcParams['ytick.color'] = '#758D99'
    plt.rcParams['figure.facecolor'] = 'white'

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {
    "Composition": [0.953, 0.168, 0.167, 2.207],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
}

properties = ["mp perovskite form E", "mp log_kvrh", "mp log_gvrh", "mp dielectric"]

# Define custom colors for each model
colors = ['#3C0753', '#720455']


# Plotting grouped bar charts
width = 0.25  # Width of each bar
fig, ax = plt.subplots(figsize=(12, 8))

for i, (model, color) in enumerate(zip(data.keys(), colors)):
    x_positions = np.arange(len(properties)) + i * width
    ax.bar(x_positions, data[model], width, label=model, color=color)

ax.set_xticks(np.arange(len(properties)) + (len(data) - 1) * width / 2)
ax.set_xticklabels(properties)
ax.set_xlabel('Properties')
ax.set_ylabel('MSError')
ax.legend()

plt.title('SLICES vs Composition')

# Save the plot in good quality as a PNG file
plt.savefig('slice_vs_composition.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {
    "CrabNet": [0.5412, 0.1471, 0.1604, 1.7288],
    "CGCNN": [0.0722, 0.1301, 0.1337, 1.8976],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
    "SOTA": [0.0554, 0.1037, 0.1078, 1.6832]
}

properties = ["mp perovskite form E", "mp log_kvrh", "mp log_gvrh", "mp dielectric"]

# Define custom colors for each model
colors = ['#030637', '#3C0753', '#720455', '#B80C09']


# Plotting grouped bar charts
width = 0.15 # Width of each bar
fig, ax = plt.subplots(figsize=(12, 8))

for i, (model, color) in enumerate(zip(data.keys(), colors)):
    x_positions = np.arange(len(properties)) + i * width
    ax.bar(x_positions, data[model], width, label=model, color=color)

ax.set_xticks(np.arange(len(properties)) + (len(data) - 1) * width / 2)
ax.set_xticklabels(properties)
ax.set_xlabel('Properties')
ax.set_ylabel('MSError')
ax.legend()

plt.title('SLICES vs SOTA')

# Save the plot in good quality as a PNG file
plt.savefig('slice_vs_sota.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = y.min(), y.max()
    x_min, x_max = x.min(), x.max()

    ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)


def set_custom_style():
    plt.rcParams['figure.figsize'] = [3.3, 2.5]
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.major.width'] = 0.5
    plt.rcParams['xtick.minor.size'] = 1.5
    plt.rcParams['xtick.minor.width'] = 0.5
    plt.rcParams['xtick.minor.visible'] = True
    plt.rcParams['xtick.top'] = False
    plt.rcParams['xtick.minor.top'] = False
    plt.rcParams['xtick.minor.bottom'] = False
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.major.width'] = 0.5
    plt.rcParams['ytick.minor.size'] = 1.5
    plt.rcParams['ytick.minor.width'] = 0.5
    plt.rcParams['ytick.minor.visible'] = True
    plt.rcParams['ytick.minor.left'] = False
    plt.rcParams['ytick.right'] = False
    plt.rcParams['axes.linewidth'] = 0.5
    plt.rcParams['grid.linewidth'] = 0.5
    plt.rcParams['lines.linewidth'] = 1.
    plt.rcParams['lines.markersize'] = 3
    plt.rcParams['axes.xmargin'] = 0
    plt.rcParams['axes.ymargin'] = 0
    plt.rcParams['legend.frameon'] = False
    plt.rcParams['axes.labelsize'] = 20
    plt.rcParams['xtick.labelsize'] = 20
    plt.rcParams['ytick.labelsize'] = 20
    plt.rcParams['legend.fontsize'] = 20
    plt.rcParams['font.size'] = 15
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['CMU Sans Serif', 'IBM Plex Sans', 'Roboto', 'Helvetica']
    plt.rcParams['mathtext.fontset'] = 'dejavusans'
    plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{amssymb} \usepackage{sfmath}'
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.axisbelow'] = True
    plt.rcParams['text.color'] = '#758D99'
    plt.rcParams['axes.labelcolor'] = '#758D99'
    plt.rcParams['axes.edgecolor'] = '#758D99'
    plt.rcParams['xtick.color'] = '#758D99'
    plt.rcParams['ytick.color'] = '#758D99'
    plt.rcParams['figure.facecolor'] = 'white'

data = {
    "Composition": [0.953, 0.168, 0.167, 2.207],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
}

properties = ["formation energy", "shear modulus", "bulk moduli", "refractive index"]

# Define custom colors for each model
colors = ['#3C0753', '#720455']


set_custom_style()
# Plotting grouped bar charts
width = 0.25  # Width of each bar
fig, ax = plt.subplots(figsize=(12, 8))

for i, (model, color) in enumerate(zip(data.keys(), colors)):
    x_positions = np.arange(len(properties)) + i * width
    ax.bar(x_positions, data[model], width, label=model, color=color)

ax.set_xticks(np.arange(len(properties)) + (len(data) - 1) * width / 2)
ax.set_xticklabels(properties)
ax.set_xlabel('Properties')
ax.set_ylabel('MSError')

ax.legend()

# Call the range_frame function
range_frame(ax, np.arange(len(properties)), np.array([data[model] for model in data.keys()]).flatten())

plt.title('SLICES vs Composition')

# Save the plot in good quality as a PNG file
plt.savefig('slice_composition.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np


def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = y.min(), y.max()
    x_min, x_max = x.min(), x.max()

    ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)


plt.rcParams['figure.figsize'] = [3.3, 2.5]
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['xtick.major.size'] = 3
plt.rcParams['xtick.major.width'] = 0.5
plt.rcParams['xtick.minor.size'] = 1.5
plt.rcParams['xtick.minor.width'] = 0.5
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['xtick.top'] = False
plt.rcParams['xtick.minor.top'] = False
plt.rcParams['xtick.minor.bottom'] = False
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['ytick.major.size'] = 3
plt.rcParams['ytick.major.width'] = 0.5
plt.rcParams['ytick.minor.size'] = 1.5
plt.rcParams['ytick.minor.width'] = 0.5
plt.rcParams['ytick.minor.visible'] = True
plt.rcParams['ytick.minor.left'] = False
plt.rcParams['ytick.right'] = False
plt.rcParams['axes.linewidth'] = 0.5
plt.rcParams['grid.linewidth'] = 0.5
plt.rcParams['lines.linewidth'] = 1.
plt.rcParams['lines.markersize'] = 3
plt.rcParams['axes.xmargin'] = 0
plt.rcParams['axes.ymargin'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['font.size'] = 10
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['CMU Sans Serif', 'IBM Plex Sans', 'Roboto', 'Helvetica']
plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{amssymb} \usepackage{sfmath}'
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.axisbelow'] = True
plt.rcParams['text.color'] = '#758D99'
plt.rcParams['axes.labelcolor'] = '#758D99'
plt.rcParams['axes.edgecolor'] = '#758D99'
plt.rcParams['xtick.color'] = '#758D99'
plt.rcParams['ytick.color'] = '#758D99'
plt.rcParams['figure.facecolor'] = 'white'


data = {
    "CrabNet": [0.5412, 0.1471, 0.1604, 1.7288],
    "CGCNN": [0.0722, 0.1301, 0.1337, 1.8976],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
    "SOTA": [0.0554, 0.1037, 0.1078, 1.6832]
}

properties = ["formation energy", "shear modulus", "bulk moduli", "refractive index"]

# Define custom colors for each model
colors = ['#030637', '#3C0753', '#720455', '#B80C09']



# Plotting grouped bar charts
width = 0.1  # Width of each bar
fig, ax = plt.subplots(figsize=(12, 8))

for i, (model, color) in enumerate(zip(data.keys(), colors)):
    x_positions = np.arange(len(properties)) + i * width
    ax.bar(x_positions, data[model], width, label=model, color=color)

ax.set_xticks(np.arange(len(properties)) + (len(data) - 1) * width / 2)
ax.set_xticklabels(properties)
ax.set_xlabel('Properties')
ax.set_ylabel('MSError')

ax.legend()

# Call the range_frame function
range_frame(ax, np.arange(len(properties)), np.array([data[model] for model in data.keys()]).flatten())

plt.title('SLICES vs Composition')

# Save the plot in good quality as a PNG file
plt.savefig('slice_2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
colors = ['#3C0753', '#720455']
plt.rcParams['figure.figsize'] = [3.3, 2.5]
def plot_property(data, properties, colors):
    width = 0.1  # Width of each bar

    for i, property in enumerate(properties):
        # Create a new figure for each property
        fig, ax = plt.subplots(figsize=(12, 8))

        # Get the data for the current property
        composition = data["Composition"][i]
        slices = data["SLICES"][i]

        # Create a bar plot comparing Composition and SLICES for the current property
        for j, (model, color) in enumerate(zip(["Composition", "SLICES"], colors)):
            ax.bar(j, [composition, slices][j], width, label=model, color=color)

        ax.set_xticks([0, 0.5])
        ax.set_xticklabels(["Composition", "SLICES"])
        ax.set_xlabel('Model')
        ax.set_ylabel('Value')
        ax.set_title(f'Comparison for {property}')

        ax.legend()

        # Call the range_frame function
        range_frame(ax, np.array([0, 1]), np.array([composition, slices]))

        # Save the plot in good quality as a PNG file
        plt.savefig(f'comparison_{property}.png', dpi=300, bbox_inches='tight')
        plt.show()

# Call the function
plot_property(data, properties, colors)

# %%
def plot_property(data, properties, colors):
    width = 0.025  # Reduced width of each bar

    # Create a new figure with 4 subplots
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    axs = axs.flatten()  # Flatten the array of axes to make it easier to iterate over

    for i, property in enumerate(properties):
        ax = axs[i]  # Get the current axes

        # Get the data for the current property
        composition = data["Composition"][i]
        slices = data["SLICES"][i]

        # Create a bar plot comparing Composition and SLICES for the current property
        for j, (model, color) in enumerate(zip(["Composition", "SLICES"], colors)):
            ax.bar(j * width, [composition, slices][j], width, label=model, color=color)

        ax.set_xticks([0, width])
        ax.set_xticklabels(["Composition", "SLICES"])
        ax.set_xlabel('Model')
        ax.set_ylabel('Value')
        ax.set_title(f'Comparison for {property}')

        ax.legend()

        # Call the range_frame function
        range_frame(ax, np.array([0, width]), np.array([composition, slices]))

    # Adjust the layout to prevent overlapping
    plt.tight_layout()

    # Save the plot in good quality as a PNG file
    plt.savefig('comparison.png', dpi=300, bbox_inches='tight')
    plt.show()

data = {
    "Composition": [0.953, 0.168, 0.167, 2.207],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
}

# Call the function
plot_property(data, properties, colors)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
data = {
    "CrabNet": [0.5412, 0.1471, 0.1604, 1.7288],
    "CGCNN": [0.0722, 0.1301, 0.1337, 1.8976],
    "SLICES": [0.095, 0.1453, 0.153, 1.766],
    "SOTA": [0.0554, 0.1037, 0.1078, 1.6832]
}

properties = ["formation energy", "shear modulus", "bulk moduli", "refractive index"]

# Define custom colors for each model
colors = ['#030637', '#3C0753', '#720455', '#B80C09']

# %%
import matplotlib.pyplot as plt



# Number of datapoints
total_datapoints = 10_000_000
labeled_percentage = 6
unlabeled_percentage = 94

# Calculate actual counts
labeled_count = (labeled_percentage / 100) * total_datapoints
unlabeled_count = (unlabeled_percentage / 100) * total_datapoints

# Plotting
labels = ['Labeled', 'Unlabeled']
sizes = [labeled_count, unlabeled_count]
colors = ['#3C0753', '#720455']

plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90)
plt.savefig('nomad.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_with_error_bars(data, property_name, temperature):
    metric_names = ['mae', 'rmse', 'mape']
    labels = list(data.keys())  # Use the keys of the outer dictionary as labels
    x = np.arange(len(labels))
    width = 0.2

    fig, ax = plt.subplots()

    for i, metric_name in enumerate(metric_names):
        mean_values = []
        std_values = []

        for label in labels:
            key = f"{property_name}"
            if key in data[label]:
                mean_values.append(data[label][key]['mean'])
                std_values.append(data[label][key]['std'])
            else:
                mean_values.append(0)
                std_values.append(0)

        ax.bar(x + i * width, mean_values, width, label=metric_name.capitalize(), yerr=std_values)

    ax.set_ylabel('Values')
    ax.set_title(f'{property_name.capitalize()} at {temperature}K')
    ax.set_xticks(x + width * (len(metric_names) - 1) / 2)
    ax.set_xticklabels(labels)
    ax.legend()

    plt.show()

# Data for 2000K
data_2000 = {
    'kvrh': {
        'mae': {'mean': 0.09389689591531483, 'std': 0.0025875145169238934},
        'rmse': {'mean': 0.14450500564528002, 'std': 0.00427475144049218},
        'mape': {'mean': 0.05943735070822263, 'std': 0.002618983312203912},
    },
    'gvrh': {
        'mae': {'mean': 0.10392290098566306, 'std': 0.0019319000511525924},
        'rmse': {'mean': 0.14904003962242046, 'std': 0.002780535332926108},
        'mape': {'mean': 0.07979616130667994, 'std': 0.001038479258755774},
    },
    'dielec': {
        'mae': {'mean': 0.3544503898388493, 'std': 0.07504084827659246},
        'rmse': {'mean': 1.7761727390550548, 'std': 0.7546649301955629},
        'mape': {'mean': 0.10222463525433208, 'std': 0.016664976341437546},
    },
    'perovskites': {
        'mae': {'mean': 0.9029617352207924, 'std': 0.01522897490543334},
        'rmse': {'mean': 1.0882545900466405, 'std': 0.01709733530196532},
        'mape': {'mean': 1.28571758736317, 'std': 0.05604625131083189},
    },
}

# Data for 300K
data_300 = {
    'dielec': {
        'mae': {'mean': 0.4282632205029751, 'std': 0.07550152138633218},
        'rmse': {'mean': 1.76693529124773, 'std': 0.7402770392400764},
        'mape': {'mean': 0.13508997218257224, 'std': 0.01567332874045981},
    },
    'kvrh': {
        'mae': {'mean': 0.08836153231258817, 'std': 0.0018887777087583822},
        'rmse': {'mean': 0.1453877620584158, 'std': 0.003789638023414889},
        'mape': {'mean': 0.057506935879848585, 'std': 0.0029123509689602187},
    },
    'gvrh': {
        'mae': {'mean': 0.10519925795361865, 'std': 0.00213866458911158},
        'rmse': {'mean': 0.15341735636403947, 'std': 0.003337234664521964},
        'mape': {'mean': 0.08159773072162013, 'std': 0.0015707691010309612},
    },
    'perovskites': {
        'mae': {'mean': 0.069765060124761, 'std': 0.002293791627810741},
        'rmse': {'mean': 0.09518802059861167, 'std': 0.003394132220771492},
        'mape': {'mean': 0.06003315434923132, 'std': 0.002088141058382794},
    },
}

# Data for 100K
data_100 = {
    'dielec': {
        'mae': {'mean': 0.42625719010964336, 'std': 0.08148134580273673},
        'rmse': {'mean': 1.8164169094258351, 'std': 0.8048660183863795},
        'mape': {'mean': 0.13547865125172948, 'std': 0.01826249355144988},
    },
    'kvrh': {
        'mae': {'mean': 0.08836153231258817, 'std': 0.0018887777087583822},
        'rmse': {'mean': 0.1453877620584158, 'std': 0.003789638023414889},
        'mape': {'mean': 0.057506935879848585, 'std': 0.0029123509689602187},
    },
    'gvrh': {
        'mae': {'mean': 0.10412660848430792, 'std': 0.0042613301212133334},
        'rmse': {'mean': 0.15952059460722806, 'std': 0.003985631880382233},
        'mape': {'mean': 0.06626878988402576, 'std': 0.0027994665026492348},
    },
    'perovskites': {
        'mae': {'mean': 0.07493171721992821, 'std': 0.002833558601227095},
        'rmse': {'mean': 0.10168782720023226, 'std': 0.004046832205957074},
        'mape': {'mean': 0.06362074178964824, 'std': 0.0018745355677818373},
    },
}
# Example usage
plot_with_error_bars(data_2000, 'kvrh', 2000)
plot_with_error_bars(data_2000, 'gvrh', 2000)
plot_with_error_bars(data_300, 'dielec', 300)
plot_with_error_bars(data_100, 'perovskites', 100)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np


def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)

def set_custom_style():
    plt.rcParams['figure.figsize'] = [3.3, 2.5]
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.major.width'] = 0.5
    plt.rcParams['xtick.minor.size'] = 1.5
    plt.rcParams['xtick.minor.width'] = 0.5
    plt.rcParams['xtick.minor.visible'] = True
    plt.rcParams['xtick.top'] = False
    plt.rcParams['xtick.minor.top'] = False
    plt.rcParams['xtick.minor.bottom'] = False
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.major.width'] = 0.5
    plt.rcParams['ytick.minor.size'] = 1.5
    plt.rcParams['ytick.minor.width'] = 0.5
    plt.rcParams['ytick.minor.visible'] = True
    plt.rcParams['ytick.minor.left'] = False
    plt.rcParams['ytick.right'] = False
    plt.rcParams['axes.linewidth'] = 0.5
    plt.rcParams['grid.linewidth'] = 0.5
    plt.rcParams['lines.linewidth'] = 1.
    plt.rcParams['lines.markersize'] = 3
    plt.rcParams['axes.xmargin'] = 0
    plt.rcParams['axes.ymargin'] = 0
    plt.rcParams['legend.frameon'] = False
    plt.rcParams['axes.labelsize'] = 11
    plt.rcParams['xtick.labelsize'] = 10
    plt.rcParams['ytick.labelsize'] = 10
    plt.rcParams['legend.fontsize'] = 10
    plt.rcParams['font.size'] = 10
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['CMU Sans Serif', 'IBM Plex Sans', 'Roboto', 'Helvetica']
    plt.rcParams['mathtext.fontset'] = 'dejavusans'
    plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{amssymb} \usepackage{sfmath}'
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.axisbelow'] = True
    plt.rcParams['text.color'] = '#758D99'
    plt.rcParams['axes.labelcolor'] = '#758D99'
    plt.rcParams['axes.edgecolor'] = '#758D99'
    plt.rcParams['xtick.color'] = '#758D99'
    plt.rcParams['ytick.color'] = '#758D99'
    plt.rcParams['figure.facecolor'] = 'white'


data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": {"mean": [0.614, 0.1016, 0.095, .108], "std": [0.02, 0.01, 0.015, 0.02]},
    "mp log_kvrh": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "mp log_gvrh": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "mp dielectric": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Handling the missing value in the provided data
data["mp perovskite form E"]["mean"][-1] = np.nan

# Transforming data to logarithmic scale
log_datasets = np.log10(datasets)
log_data = {prop: {"mean": np.log10(values["mean"]), "std": values["std"]} if prop != "Dataset" else values for prop, values in data.items()}

# Set custom style
set_custom_style()

# Plotting line charts with error bars
fig, ax = plt.subplots(figsize=(10, 6))

for prop in properties:
    mean_values = log_data[prop]["mean"]
    std_values = log_data[prop]["std"]
    ax.errorbar(log_datasets, mean_values, yerr=std_values, label=prop, marker='o')

ax.set_ylim(-1.2, 0.4)

# Apply the range frame
range_frame(ax, log_datasets, np.concatenate([log_data[prop]["mean"] for prop in properties]))

# Set font size
# fontsize = 24

ax.set_xlabel('log ( Dataset size in thousands)')
ax.set_ylabel('log (RMSError)')
ax.legend()

# plt.title('SLICES Learning with Error Bars (log scale)')

# Save the plot in good quality as a PNG file
plt.savefig('slice_log_line_plot_with_error_bars.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np


import matplotlib.pyplot as plt
import numpy as np


def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)


plt.rcParams['figure.figsize'] = [3.3, 2.5]
plt.rcParams['xtick.direction'] = 'in'

data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
    "mp log_kvrh": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "mp log_gvrh": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "mp dielectric": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}
# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]



# Transforming data to logarithmic scale
log_datasets = np.log10(datasets)
log_data = {
    prop: np.log10(prop_values["mean"]) if isinstance(prop_values, dict) else np.log10(prop_values)
    for prop, prop_values in data.items()
}

# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

for prop in properties:
    if prop == "Dataset":
        continue  # Skip plotting "Dataset"
    
    if isinstance(data[prop], dict):
        mean_values = np.log10(data[prop]["mean"])
        std_values = data[prop]["std"]
    else:
        mean_values = np.log10(data[prop])
        std_values = None

    ax.errorbar(log_datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)

# Apply the range frame
range_frame(ax, log_datasets, np.concatenate([log_data[prop] for prop in properties]))

ax.set_xlabel('log (Dataset size in thousands)')
ax.set_ylabel('log (RMSError)')
ax.legend()

# plt.title('SLICES Learning (log scale)')

# Save the plot in good quality as a PNG file
plt.savefig('slice_log_line_plot_properties_00.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
def set_custom_style():
    plt.rcParams['figure.figsize'] = [3.3, 2.5]
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.major.width'] = 0.5
    plt.rcParams['xtick.minor.size'] = 1.5
    plt.rcParams['xtick.minor.width'] = 0.5
    plt.rcParams['xtick.minor.visible'] = True
    plt.rcParams['xtick.top'] = False
    plt.rcParams['xtick.minor.top'] = False
    plt.rcParams['xtick.minor.bottom'] = False
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.major.width'] = 0.5
    plt.rcParams['ytick.minor.size'] = 1.5
    plt.rcParams['ytick.minor.width'] = 0.5
    plt.rcParams['ytick.minor.visible'] = True
    plt.rcParams['ytick.minor.left'] = False
    plt.rcParams['ytick.right'] = False
    plt.rcParams['axes.linewidth'] = 0.5
    plt.rcParams['grid.linewidth'] = 0.5
    plt.rcParams['lines.linewidth'] = 1.
    plt.rcParams['lines.markersize'] = 3
    plt.rcParams['axes.xmargin'] = 0
    plt.rcParams['axes.ymargin'] = 0
    plt.rcParams['legend.frameon'] = False
    plt.rcParams['axes.labelsize'] = 11
    plt.rcParams['xtick.labelsize'] = 10
    plt.rcParams['ytick.labelsize'] = 10
    plt.rcParams['legend.fontsize'] = 10
    plt.rcParams['font.size'] = 10
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['CMU Sans Serif', 'IBM Plex Sans', 'Roboto', 'Helvetica']
    plt.rcParams['mathtext.fontset'] = 'dejavusans'
    plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{amssymb} \usepackage{sfmath}'
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.axisbelow'] = True
    plt.rcParams['text.color'] = '#758D99'
    plt.rcParams['axes.labelcolor'] = '#758D99'
    plt.rcParams['axes.edgecolor'] = '#758D99'
    plt.rcParams['xtick.color'] = '#758D99'
    plt.rcParams['ytick.color'] = '#758D99'
    plt.rcParams['figure.facecolor'] = 'white'

# %%
import matplotlib.pyplot as plt
import numpy as np


import matplotlib.pyplot as plt
import numpy as np


def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)


plt.rcParams['figure.figsize'] = [3.3, 2.5]
plt.rcParams['xtick.direction'] = 'in'

data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
    "mp log_kvrh": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "mp log_gvrh": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "mp dielectric": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}
# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]



# Transforming data to logarithmic scale
log_datasets = np.log10(datasets)
log_data = {
    prop: np.log10(prop_values["mean"]) if isinstance(prop_values, dict) else np.log10(prop_values)
    for prop, prop_values in data.items()
}

set_custom_style()
# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

for prop in properties:
    if prop == "Dataset":
        continue  # Skip plotting "Dataset"
    
    if isinstance(data[prop], dict):
        mean_values = np.log10(data[prop]["mean"])
        std_values = np.log10(data[prop]["std"]) if "std" in data[prop] else None
    else:
        mean_values = np.log10(data[prop])
        std_values = None

    ax.errorbar(log_datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)

# Apply the range frame
#range_frame(ax, log_datasets, np.concatenate([log_data[prop] for prop in properties]))

ax.set_xlabel('log (Dataset size in thousands)')
ax.set_ylabel('log (RMSError)')
ax.legend()

# plt.title('SLICES Learning (log scale)')

# Save the plot in good quality as a PNG file
plt.savefig('slice_log_line_plot_properties_00.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 63
#      60         mean_values = np.log10(data[prop])
#      61         std_values = None
# ---> 63     ax.errorbar(log_datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)
#      65 # Apply the range frame
#      66 #range_frame(ax, log_datasets, np.concatenate([log_data[prop] for prop in properties]))
#      68 ax.set_xlabel('log (Dataset size in thousands)')
#
# File ~/miniconda3/envs/slice_llm/lib/python3.9/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %%
data_composition = {
    "Dataset": [20, 100, 300, 2000],
    "dielectric": {"mean": [2.0295, 2.0789, 2.0416, 2.2753], "std": [0.5948, 0.5609, 0.7676, 0.4653]},
    "log_gvrh": {"mean": [0.1725, 0.1695, 0.1681, 0.1647], "std": [0.0086, 0.0057, 0.0063, 0.0065]},
    "logkvrh": {"mean": [0.1707, 0.1696, 0.1653, 0.1653], "std": [0.0077, 0.0057, 0.0047, 0.0047]},
    "perovskites": {"mean": [0.9736, 0.9852, 0.9918, 0.9918], "std": [0.0132, 0.0117, 0.0126, 0.0126]},
}


data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
    "mp log_kvrh": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "mp log_gvrh": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "mp dielectric": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}

# %%
data_composition = {
    "Dataset": [20, 100, 300, 2000],
    "dielectric": {"mean": [2.0295, 2.0789, 2.0416, 2.2753], "std": [0.5948, 0.5609, 0.7676, 0.4653]},
    "log_gvrh": {"mean": [0.1725, 0.1695, 0.1681, 0.1647], "std": [0.0086, 0.0057, 0.0063, 0.0065]},
    "logkvrh": {"mean": [0.1707, 0.1696, 0.1653, 0.1653], "std": [0.0077, 0.0057, 0.0047, 0.0047]},
    "perovskites": {"mean": [0.9736, 0.9852, 0.9918, 0.9918], "std": [0.0132, 0.0117, 0.0126, 0.0126]},
}


data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
    "mp log_kvrh": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "mp log_gvrh": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "mp dielectric": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}

# %%
import matplotlib.pyplot as plt
import numpy as np

def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)

plt.rcParams['figure.figsize'] = [3.3, 2.5]
plt.rcParams['xtick.direction'] = 'in'

data = {
    "Dataset": [20, 100, 300, 2000],
    "composition": {"mean": [0.1707, 0.1696, 0.1653, 0.1653], "std": [0.0077, 0.0057, 0.0047, 0.0047]},
    "slice": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Set font size
fontsize = 50

# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

# Set y-axis limits
ax.set_ylim(0.4, 1.6)  # Adjusted the y-axis limits for better visualization

for prop in properties:
    if prop == "Dataset":
        continue  # Skip plotting "Dataset"

    mean_values = data[prop]["mean"]
    std_values = data[prop]["std"]

    if std_values is not None:
        ax.errorbar(datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)
    else:
        ax.errorbar(datasets, mean_values, label=prop, marker='o', linestyle='-', capsize=3)

# Apply the range frame
range_frame(ax, datasets, np.concatenate([data[prop]["mean"] for prop in properties]))

ax.set_xlabel('Dataset size in thousands')
ax.set_ylabel('RMSError')
ax.set_title('perovksites')
ax.legend()

# Save the plot in good quality as a PNG file
plt.savefig('slice_comp_perovksites_not_log.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
#   Cell In[17], line 28
#     datasets = data["Dataset"]
#              ^
# SyntaxError: invalid syntax

# %%
def set_custom_style():
    plt.rcParams['figure.figsize'] = [3.3, 2.5]
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.major.width'] = 0.5
    plt.rcParams['xtick.minor.size'] = 1.5
    plt.rcParams['xtick.minor.width'] = 0.5
    plt.rcParams['xtick.minor.visible'] = True
    plt.rcParams['xtick.top'] = False
    plt.rcParams['xtick.minor.top'] = False
    plt.rcParams['xtick.minor.bottom'] = False
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.major.width'] = 0.5
    plt.rcParams['ytick.minor.size'] = 1.5
    plt.rcParams['ytick.minor.width'] = 0.5
    plt.rcParams['ytick.minor.visible'] = True
    plt.rcParams['ytick.minor.left'] = False
    plt.rcParams['ytick.right'] = False
    plt.rcParams['axes.linewidth'] = 0.5
    plt.rcParams['grid.linewidth'] = 0.5
    plt.rcParams['lines.linewidth'] = 1.
    plt.rcParams['lines.markersize'] = 3
    plt.rcParams['axes.xmargin'] = 0
    plt.rcParams['axes.ymargin'] = 0
    plt.rcParams['legend.frameon'] = False
    plt.rcParams['axes.labelsize'] = 20
    plt.rcParams['xtick.labelsize'] = 20
    plt.rcParams['ytick.labelsize'] = 20
    plt.rcParams['legend.fontsize'] = 20
    plt.rcParams['font.size'] = 15
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['CMU Sans Serif', 'IBM Plex Sans', 'Roboto', 'Helvetica']
    plt.rcParams['mathtext.fontset'] = 'dejavusans'
    plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{amssymb} \usepackage{sfmath}'
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.axisbelow'] = True
    plt.rcParams['text.color'] = '#758D99'
    plt.rcParams['axes.labelcolor'] = '#758D99'
    plt.rcParams['axes.edgecolor'] = '#758D99'
    plt.rcParams['xtick.color'] = '#758D99'
    plt.rcParams['ytick.color'] = '#758D99'
    plt.rcParams['figure.facecolor'] = 'white'

# %%
import matplotlib.pyplot as plt
import numpy as np

def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)

plt.rcParams['figure.figsize'] = [3.3, 2.5]
plt.rcParams['xtick.direction'] = 'in'

data = {
    "Dataset": [20, 100, 300, 2000],
    "composition": {"mean": [0.9736, 0.9852, 0.9918, 0.9918], "std": [0.0132, 0.0117, 0.0126, 0.0126]},
    "slice": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Transforming data to logarithmic scale
log_datasets = np.log10(datasets)
log_data = {
    prop: {
        "mean": np.log10(prop_values["mean"]) if isinstance(prop_values, dict) else np.log10(prop_values),
        "std": np.abs(prop_values["std"]) if isinstance(prop_values, dict) and "std" in prop_values else None
    }
    for prop, prop_values in data.items()
}
# Set font size
fontsize = 50
set_custom_style()
# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

# Set y-axis limits
ax.set_ylim(0, 2)

for prop in properties:
    if prop == "Dataset":
        continue  # Skip plotting "Dataset"

    mean_values = log_data[prop]["mean"]
    std_values = log_data[prop]["std"]

    ax.errorbar(log_datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)

# Apply the range frame
range_frame(ax, log_datasets, np.concatenate([log_data[prop]["mean"] for prop in properties]))

ax.set_xlabel('log (Dataset size in thousands)')
ax.set_ylabel('log (RMSError)')
ax.set_title('perovksites')
ax.legend()

# Save the plot in good quality as a PNG file
plt.savefig('slice_comp_perovksites_3.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
data_composition = {
    "Dataset": [20, 100, 300, 2000],
    "dielectric": {"mean": [2.0295, 2.0789, 2.0416, 2.2753], "std": [0.5948, 0.5609, 0.7676, 0.4653]},
    "log_gvrh": {"mean": [0.1725, 0.1695, 0.1681, 0.1647], "std": [0.0086, 0.0057, 0.0063, 0.0065]},
    "logkvrh": {"mean": [0.1707, 0.1696, 0.1653, 0.1653], "std": [0.0077, 0.0057, 0.0047, 0.0047]},
    "perovskites": {"mean": [0.9736, 0.9852, 0.9918, 0.9918], "std": [0.0132, 0.0117, 0.0126, 0.0126]},
}


data = {
    "Dataset": [20, 100, 300, 2000],
    "mp perovskite form E": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
    "mp log_kvrh": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "mp log_gvrh": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "mp dielectric": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}

# %%
import matplotlib.pyplot as plt
import numpy as np

def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)

# plt.rcParams['figure.figsize'] = [3.3, 2.5]
# plt.rcParams['xtick.direction'] = 'in'

data = {
    "Dataset": [20, 100, 300, 2000],
    "composition":  {"mean": [2.0295, 2.0789, 2.0416, 2.2753], "std": [0.5948, 0.5609, 0.7676, 0.4653]},
    "slice":  {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Transforming data to logarithmic scale
log_datasets = (datasets)
log_data = {
    prop: {
        "mean": (prop_values["mean"]) if isinstance(prop_values, dict) else (prop_values),
        "std": np.abs(prop_values["std"]) if isinstance(prop_values, dict) and "std" in prop_values else None
    }
    for prop, prop_values in data.items()
}
# Set font size
fontsize = 50

# set_custom_style()
# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))

# Set y-axis limits
ax.set_ylim(0, 2)

for prop in properties:
    if prop == "Dataset":
        continue  # Skip plotting "Dataset"

    mean_values = log_data[prop]["mean"]
    std_values = log_data[prop]["std"]

    ax.errorbar(log_datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)

# Apply the range frame
range_frame(ax, log_datasets, np.concatenate([log_data[prop]["mean"] for prop in properties]))

ax.set_xlabel('log (Dataset size in thousands)')
ax.set_ylabel('log (RMSError)')
ax.set_title('dielec')
ax.legend()

# Save the plot in good quality as a PNG file
plt.savefig('slice_comp_dielec_1.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...

# %%
composition = {
    "Dataset": [20, 100, 300, 2000],
    "Refractive Index": {"mean": [2.0295, 2.0789, 2.0416, 2.2753], "std": [0.5948, 0.5609, 0.7676, 0.4653]},
    "Bulk Modulus": {"mean": [0.1725, 0.1695, 0.1681, 0.1647], "std": [0.0086, 0.0057, 0.0063, 0.0065]},
    "Shear Modulus": {"mean": [0.1707, 0.1696, 0.1653, 0.1653], "std": [0.0077, 0.0057, 0.0047, 0.0047]},
    "Formation Energy Perovksites": {"mean": [0.9736, 0.9852, 0.9918, 0.9918], "std": [0.0132, 0.0117, 0.0126, 0.0126]},
}


slices = {
    "Dataset": [20, 100, 300, 2000],
    "Formation Energy Perovksites": {"mean": [0.614, 0.1016, 0.095, 0.1044], "std": [0.008, 0.01, 0.015, 0.02]},
    "Shear Modulus": {"mean": [0.296, 0.15726, 0.1453, 0.144], "std": [0.01, 0.005, 0.008, 0.01]},
    "Bulk Modulus": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
    "Refractive Index": {"mean": [1.902, 1.81, 1.766, 1.776], "std": [0.05, 0.02, 0.03, 0.04]},
}

# %%
import matplotlib.pyplot as plt
import numpy as np

def range_frame(ax, x, y, pad=0.1):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    x_min, x_max = np.nanmin(x), np.nanmax(x)

    if np.isfinite(y_min) and np.isfinite(y_max):
        ax.set_ylim(y_min - pad * (y_max - y_min), y_max + pad * (y_max - y_min))
    if np.isfinite(x_min) and np.isfinite(x_max):
        ax.set_xlim(x_min - pad * (x_max - x_min), x_max + pad * (x_max - x_min))

    ax.spines["left"].set_position(("outward", 10))
    ax.spines["bottom"].set_position(("outward", 10))

    ax.spines["bottom"].set_bounds(x_min, x_max)
    ax.spines["left"].set_bounds(y_min, y_max)

plt.rcParams['figure.figsize'] = [3.3, 2.5]
plt.rcParams['xtick.direction'] = 'in'

data = {
    "Dataset": [20, 100, 300, 2000],
    "composition": {"mean": [0.1707, 0.1696, 0.1653, 0.1653], "std": [0.0077, 0.0057, 0.0047, 0.0047]},
    "slice": {"mean": [0.298, 0.165, 0.153, 0.149], "std": [0.012, 0.008, 0.01, 0.015]},
}

# Extracting dataset values and property names
datasets = data["Dataset"]
properties = list(data.keys())[1:]

# Set font size
fontsize = 50

# Plotting line charts
fig, ax = plt.subplots(figsize=(10, 6))



for prop in properties:
    if prop == "Dataset":
        continue  # Skip plotting "Dataset"

    mean_values = data[prop]["mean"]
    std_values = data[prop]["std"]

    if std_values is not None:
        ax.errorbar(datasets, mean_values, yerr=std_values, label=prop, marker='o', linestyle='-', capsize=3)
    else:
        ax.errorbar(datasets, mean_values, label=prop, marker='o', linestyle='-', capsize=3)

# Apply the range frame
range_frame(ax, datasets, np.concatenate([data[prop]["mean"] for prop in properties]))

# Set y-axis limits
#ax.set_ylim(1, 4)  # Adjusted the y-axis limits for better visualization

ax.set_xlabel('Dataset size in thousands')
ax.set_ylabel('RMSError')
ax.set_title("Shear Modulus")
ax.legend()

# Save the plot in good quality as a PNG file
plt.savefig('slice_comp_Shear_Modulus_3.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: CMU Sans Serif, IBM Plex Sans, Roboto, Helvetica
# ...
